# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_folder = "../../Datasets/HUPA-UCM Diabetes Dataset/Preprocessed"
output_folder = "../../Datasets/HUPA-UCM Diabetes Dataset/Cleaned"
eda_output_folder = "../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs"

# %%
os.makedirs(output_folder, exist_ok=True)
os.makedirs(eda_output_folder, exist_ok=True)

# %%
sys.path.append("../../src")  

from utils.hupa_ucm.hupa_ucm_checks import (
    show_info,
    show_shape,
    check_missing,
    check_duplicates,
    check_outliers
)

from eda.hupa_ucm.hupa_ucm_plots import (
    plot_outliers,
    plot_distributions
)

from eda.hupa_ucm.hupa_ucm_runner import run_eda_on_folder

# %%
# Run basic checks
print(" BASIC INFO ")
run_eda_on_folder(data_folder, funcs=[show_info])

print("\nSHAPE ")
run_eda_on_folder(data_folder, funcs=[show_shape])

print("\MISSING VALUES ")
run_eda_on_folder(data_folder, funcs=[check_missing])

print("\nDUPLICATES ")
run_eda_on_folder(data_folder, funcs=[check_duplicates])

print("\n OUTLIERS ")
run_eda_on_folder(data_folder, funcs=[check_outliers])
# Out:
# === BASIC INFO ===
# Found CSV files: ['HUPA0002P.csv', 'HUPA0027P.csv', 'HUPA0020P.csv', 'HUPA0011P.csv', 'HUPA0007P.csv', 'HUPA0018P.csv', 'HUPA0028P.csv', 'HUPA0003P.csv', 'HUPA0022P.csv', 'HUPA0026P.csv', 'HUPA0025P.csv', 'HUPA0023P.csv', 'HUPA0005P.csv', 'HUPA0014P.csv', 'HUPA0001P.csv', 'HUPA0006P.csv', 'HUPA0010P.csv', 'HUPA0016P.csv', 'HUPA0021P.csv', 'HUPA0017P.csv', 'HUPA0024P.csv', 'HUPA0004P.csv', 'HUPA0009P.csv', 'HUPA0015P.csv', 'HUPA0019P.csv']
# ********************
# ************************************************************
# File: HUPA0002P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3181 entries, 0 to 3180
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3181 non-null   object
#  1   glucose                 3181 non-null   float64
#  2   calories                3181 non-null   float64
#  3   heart_rate              3181 non-null   float64
#  4   steps                   3181 non-null   float64
#  5   basal_rate              3181 non-null   float64
#  6   bolus_volume_delivered  3181 non-null   float64
#  7   carb_input              3181 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 198.9+ KB
# None
# ********************
# ************************************************************
# File: HUPA0027P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165306 entries, 0 to 165305
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   time                    165306 non-null  object
#  1   glucose                 165306 non-null  float64
#  2   calories                165306 non-null  float64
#  3   heart_rate              165306 non-null  float64
#  4   steps                   165306 non-null  float64
#  5   basal_rate              165306 non-null  float64
#  6   bolus_volume_delivered  165306 non-null  float64
#  7   carb_input              165306 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 10.1+ MB
# None
# ********************
# ************************************************************
# File: HUPA0020P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2862 entries, 0 to 2861
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    2862 non-null   object
#  1   glucose                 2862 non-null   float64
#  2   calories                2862 non-null   float64
#  3   heart_rate              2862 non-null   float64
#  4   steps                   2862 non-null   float64
#  5   basal_rate              2862 non-null   float64
#  6   bolus_volume_delivered  2862 non-null   float64
#  7   carb_input              2862 non-null   int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 179.0+ KB
# None
# ********************
# ************************************************************
# File: HUPA0011P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3839 entries, 0 to 3838
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3839 non-null   object
#  1   glucose                 3839 non-null   float64
#  2   calories                3839 non-null   float64
#  3   heart_rate              3839 non-null   float64
#  4   steps                   3839 non-null   float64
#  5   basal_rate              3839 non-null   int64
#  6   bolus_volume_delivered  3839 non-null   int64
#  7   carb_input              3839 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 240.1+ KB
# None
# ********************
# ************************************************************
# File: HUPA0007P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3857 entries, 0 to 3856
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3857 non-null   object
#  1   glucose                 3857 non-null   float64
#  2   calories                3857 non-null   float64
#  3   heart_rate              3857 non-null   float64
#  4   steps                   3857 non-null   float64
#  5   basal_rate              3857 non-null   float64
#  6   bolus_volume_delivered  3857 non-null   float64
#  7   carb_input              3857 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 241.2+ KB
# None
# ********************
# ************************************************************
# File: HUPA0018P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3895 entries, 0 to 3894
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3895 non-null   object
#  1   glucose                 3895 non-null   float64
#  2   calories                3895 non-null   float64
#  3   heart_rate              3895 non-null   float64
#  4   steps                   3895 non-null   float64
#  5   basal_rate              3895 non-null   int64
#  6   bolus_volume_delivered  3895 non-null   int64
#  7   carb_input              3895 non-null   int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 243.6+ KB
# None
# ********************
# ************************************************************
# File: HUPA0028P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25902 entries, 0 to 25901
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    25902 non-null  object
#  1   glucose                 25902 non-null  float64
#  2   calories                25902 non-null  float64
#  3   heart_rate              25902 non-null  float64
#  4   steps                   25902 non-null  float64
#  5   basal_rate              25902 non-null  float64
#  6   bolus_volume_delivered  25902 non-null  float64
#  7   carb_input              25902 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 1.6+ MB
# None
# ********************
# ************************************************************
# File: HUPA0003P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3770 entries, 0 to 3769
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3770 non-null   object
#  1   glucose                 3770 non-null   float64
#  2   calories                3770 non-null   float64
#  3   heart_rate              3770 non-null   float64
#  4   steps                   3770 non-null   float64
#  5   basal_rate              3770 non-null   float64
#  6   bolus_volume_delivered  3770 non-null   float64
#  7   carb_input              3770 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 235.8+ KB
# None
# ********************
# ************************************************************
# File: HUPA0022P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4023 entries, 0 to 4022
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    4023 non-null   object
#  1   glucose                 4023 non-null   float64
#  2   calories                4023 non-null   float64
#  3   heart_rate              4023 non-null   float64
#  4   steps                   4023 non-null   float64
#  5   basal_rate              4023 non-null   float64
#  6   bolus_volume_delivered  4023 non-null   float64
#  7   carb_input              4023 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 251.6+ KB
# None
# ********************
# ************************************************************
# File: HUPA0026P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40605 entries, 0 to 40604
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    40605 non-null  object
#  1   glucose                 40605 non-null  float64
#  2   calories                40605 non-null  float64
#  3   heart_rate              40605 non-null  float64
#  4   steps                   40605 non-null  float64
#  5   basal_rate              40605 non-null  float64
#  6   bolus_volume_delivered  40605 non-null  float64
#  7   carb_input              40605 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 2.5+ MB
# None
# ********************
# ************************************************************
# File: HUPA0025P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4006 entries, 0 to 4005
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    4006 non-null   object
#  1   glucose                 4006 non-null   float64
#  2   calories                4006 non-null   float64
#  3   heart_rate              4006 non-null   float64
#  4   steps                   4006 non-null   float64
#  5   basal_rate              4006 non-null   float64
#  6   bolus_volume_delivered  4006 non-null   float64
#  7   carb_input              4006 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 250.5+ KB
# None
# ********************
# ************************************************************
# File: HUPA0023P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3919 entries, 0 to 3918
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3919 non-null   object
#  1   glucose                 3919 non-null   float64
#  2   calories                3919 non-null   float64
#  3   heart_rate              3919 non-null   float64
#  4   steps                   3919 non-null   float64
#  5   basal_rate              3919 non-null   float64
#  6   bolus_volume_delivered  3919 non-null   float64
#  7   carb_input              3919 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 245.1+ KB
# None
# ********************
# ************************************************************
# File: HUPA0005P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3858 entries, 0 to 3857
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3858 non-null   object
#  1   glucose                 3858 non-null   float64
#  2   calories                3858 non-null   float64
#  3   heart_rate              3858 non-null   float64
#  4   steps                   3858 non-null   float64
#  5   basal_rate              3858 non-null   float64
#  6   bolus_volume_delivered  3858 non-null   float64
#  7   carb_input              3858 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 241.3+ KB
# None
# ********************
# ************************************************************
# File: HUPA0014P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3829 entries, 0 to 3828
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3829 non-null   object
#  1   glucose                 3829 non-null   float64
#  2   calories                3829 non-null   float64
#  3   heart_rate              3829 non-null   float64
#  4   steps                   3829 non-null   float64
#  5   basal_rate              3829 non-null   int64
#  6   bolus_volume_delivered  3829 non-null   float64
#  7   carb_input              3829 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 239.4+ KB
# None
# ********************
# ************************************************************
# File: HUPA0001P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4096 entries, 0 to 4095
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    4096 non-null   object
#  1   glucose                 4096 non-null   float64
#  2   calories                4096 non-null   float64
#  3   heart_rate              4096 non-null   float64
#  4   steps                   4096 non-null   float64
#  5   basal_rate              4096 non-null   float64
#  6   bolus_volume_delivered  4096 non-null   float64
#  7   carb_input              4096 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 256.1+ KB
# None
# ********************
# ************************************************************
# File: HUPA0006P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    2290 non-null   object
#  1   glucose                 2290 non-null   float64
#  2   calories                2290 non-null   float64
#  3   heart_rate              2290 non-null   float64
#  4   steps                   2290 non-null   float64
#  5   basal_rate              2290 non-null   float64
#  6   bolus_volume_delivered  2290 non-null   float64
#  7   carb_input              2290 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 143.3+ KB
# None
# ********************
# ************************************************************
# File: HUPA0010P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2976 entries, 0 to 2975
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    2976 non-null   object
#  1   glucose                 2976 non-null   float64
#  2   calories                2976 non-null   float64
#  3   heart_rate              2976 non-null   float64
#  4   steps                   2976 non-null   float64
#  5   basal_rate              2976 non-null   float64
#  6   bolus_volume_delivered  2976 non-null   float64
#  7   carb_input              2976 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 186.1+ KB
# None
# ********************
# ************************************************************
# File: HUPA0016P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3835 entries, 0 to 3834
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3835 non-null   object
#  1   glucose                 3835 non-null   float64
#  2   calories                3835 non-null   float64
#  3   heart_rate              3835 non-null   float64
#  4   steps                   3835 non-null   float64
#  5   basal_rate              3835 non-null   float64
#  6   bolus_volume_delivered  3835 non-null   float64
#  7   carb_input              3835 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 239.8+ KB
# None
# ********************
# ************************************************************
# File: HUPA0021P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2343 entries, 0 to 2342
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    2343 non-null   object
#  1   glucose                 2343 non-null   float64
#  2   calories                2343 non-null   float64
#  3   heart_rate              2343 non-null   float64
#  4   steps                   2343 non-null   float64
#  5   basal_rate              2343 non-null   float64
#  6   bolus_volume_delivered  2343 non-null   float64
#  7   carb_input              2343 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 146.6+ KB
# None
# ********************
# ************************************************************
# File: HUPA0017P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3599 entries, 0 to 3598
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3599 non-null   object
#  1   glucose                 3599 non-null   float64
#  2   calories                3599 non-null   float64
#  3   heart_rate              3599 non-null   float64
#  4   steps                   3599 non-null   float64
#  5   basal_rate              3599 non-null   float64
#  6   bolus_volume_delivered  3599 non-null   float64
#  7   carb_input              3599 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 225.1+ KB
# None
# ********************
# ************************************************************
# File: HUPA0024P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2902 entries, 0 to 2901
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    2902 non-null   object
#  1   glucose                 2902 non-null   float64
#  2   calories                2902 non-null   float64
#  3   heart_rate              2902 non-null   float64
#  4   steps                   2902 non-null   float64
#  5   basal_rate              2902 non-null   float64
#  6   bolus_volume_delivered  2902 non-null   float64
#  7   carb_input              2902 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 181.5+ KB
# None
# ********************
# ************************************************************
# File: HUPA0004P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3184 entries, 0 to 3183
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3184 non-null   object
#  1   glucose                 3184 non-null   float64
#  2   calories                3184 non-null   float64
#  3   heart_rate              3184 non-null   float64
#  4   steps                   3184 non-null   float64
#  5   basal_rate              3184 non-null   float64
#  6   bolus_volume_delivered  3184 non-null   float64
#  7   carb_input              3184 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 199.1+ KB
# None
# ********************
# ************************************************************
# File: HUPA0009P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3812 entries, 0 to 3811
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3812 non-null   object
#  1   glucose                 3812 non-null   float64
#  2   calories                3812 non-null   float64
#  3   heart_rate              3812 non-null   float64
#  4   steps                   3812 non-null   float64
#  5   basal_rate              3812 non-null   float64
#  6   bolus_volume_delivered  3812 non-null   float64
#  7   carb_input              3812 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 238.4+ KB
# None
# ********************
# ************************************************************
# File: HUPA0015P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3792 entries, 0 to 3791
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3792 non-null   object
#  1   glucose                 3792 non-null   float64
#  2   calories                3792 non-null   float64
#  3   heart_rate              3792 non-null   float64
#  4   steps                   3792 non-null   float64
#  5   basal_rate              3792 non-null   int64
#  6   bolus_volume_delivered  3792 non-null   int64
#  7   carb_input              3792 non-null   int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 237.1+ KB
# None
# ********************
# ************************************************************
# File: HUPA0019P.csv
#
#  Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3711 entries, 0 to 3710
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    3711 non-null   object
#  1   glucose                 3711 non-null   float64
#  2   calories                3711 non-null   float64
#  3   heart_rate              3711 non-null   float64
#  4   steps                   3711 non-null   float64
#  5   basal_rate              3711 non-null   float64
#  6   bolus_volume_delivered  3711 non-null   float64
#  7   carb_input              3711 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 232.1+ KB
# None
# ********************
#
# === SHAPE ===
# Found CSV files: ['HUPA0002P.csv', 'HUPA0027P.csv', 'HUPA0020P.csv', 'HUPA0011P.csv', 'HUPA0007P.csv', 'HUPA0018P.csv', 'HUPA0028P.csv', 'HUPA0003P.csv', 'HUPA0022P.csv', 'HUPA0026P.csv', 'HUPA0025P.csv', 'HUPA0023P.csv', 'HUPA0005P.csv', 'HUPA0014P.csv', 'HUPA0001P.csv', 'HUPA0006P.csv', 'HUPA0010P.csv', 'HUPA0016P.csv', 'HUPA0021P.csv', 'HUPA0017P.csv', 'HUPA0024P.csv', 'HUPA0004P.csv', 'HUPA0009P.csv', 'HUPA0015P.csv', 'HUPA0019P.csv']
# ********************
# ************************************************************
# File: HUPA0002P.csv
#
#  Shape (rows, cols): (3181, 8)
# ********************
# ************************************************************
# File: HUPA0027P.csv
#
#  Shape (rows, cols): (165306, 8)
# ********************
# ************************************************************
# File: HUPA0020P.csv
#
#  Shape (rows, cols): (2862, 8)
# ********************
# ************************************************************
# File: HUPA0011P.csv
#
#  Shape (rows, cols): (3839, 8)
# ********************
# ************************************************************
# File: HUPA0007P.csv
#
#  Shape (rows, cols): (3857, 8)
# ********************
# ************************************************************
# File: HUPA0018P.csv
#
#  Shape (rows, cols): (3895, 8)
# ********************
# ************************************************************
# File: HUPA0028P.csv
#
#  Shape (rows, cols): (25902, 8)
# ********************
# ************************************************************
# File: HUPA0003P.csv
#
#  Shape (rows, cols): (3770, 8)
# ********************
# ************************************************************
# File: HUPA0022P.csv
#
#  Shape (rows, cols): (4023, 8)
# ********************
# ************************************************************
# File: HUPA0026P.csv
#
#  Shape (rows, cols): (40605, 8)
# ********************
# ************************************************************
# File: HUPA0025P.csv
#
#  Shape (rows, cols): (4006, 8)
# ********************
# ************************************************************
# File: HUPA0023P.csv
#
#  Shape (rows, cols): (3919, 8)
# ********************
# ************************************************************
# File: HUPA0005P.csv
#
#  Shape (rows, cols): (3858, 8)
# ********************
# ************************************************************
# File: HUPA0014P.csv
#
#  Shape (rows, cols): (3829, 8)
# ********************
# ************************************************************
# File: HUPA0001P.csv
#
#  Shape (rows, cols): (4096, 8)
# ********************
# ************************************************************
# File: HUPA0006P.csv
#
#  Shape (rows, cols): (2290, 8)
# ********************
# ************************************************************
# File: HUPA0010P.csv
#
#  Shape (rows, cols): (2976, 8)
# ********************
# ************************************************************
# File: HUPA0016P.csv
#
#  Shape (rows, cols): (3835, 8)
# ********************
# ************************************************************
# File: HUPA0021P.csv
#
#  Shape (rows, cols): (2343, 8)
# ********************
# ************************************************************
# File: HUPA0017P.csv
#
#  Shape (rows, cols): (3599, 8)
# ********************
# ************************************************************
# File: HUPA0024P.csv
#
#  Shape (rows, cols): (2902, 8)
# ********************
# ************************************************************
# File: HUPA0004P.csv
#
#  Shape (rows, cols): (3184, 8)
# ********************
# ************************************************************
# File: HUPA0009P.csv
#
#  Shape (rows, cols): (3812, 8)
# ********************
# ************************************************************
# File: HUPA0015P.csv
#
#  Shape (rows, cols): (3792, 8)
# ********************
# ************************************************************
# File: HUPA0019P.csv
#
#  Shape (rows, cols): (3711, 8)
# ********************
#
# === MISSING VALUES ===
# Found CSV files: ['HUPA0002P.csv', 'HUPA0027P.csv', 'HUPA0020P.csv', 'HUPA0011P.csv', 'HUPA0007P.csv', 'HUPA0018P.csv', 'HUPA0028P.csv', 'HUPA0003P.csv', 'HUPA0022P.csv', 'HUPA0026P.csv', 'HUPA0025P.csv', 'HUPA0023P.csv', 'HUPA0005P.csv', 'HUPA0014P.csv', 'HUPA0001P.csv', 'HUPA0006P.csv', 'HUPA0010P.csv', 'HUPA0016P.csv', 'HUPA0021P.csv', 'HUPA0017P.csv', 'HUPA0024P.csv', 'HUPA0004P.csv', 'HUPA0009P.csv', 'HUPA0015P.csv', 'HUPA0019P.csv']
# ********************
# ************************************************************
# File: HUPA0002P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0027P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0020P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0011P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0007P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0018P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0028P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0003P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0022P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0026P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0025P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0023P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0005P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0014P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0001P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0006P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0010P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0016P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0021P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0017P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0024P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0004P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0009P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0015P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
# ************************************************************
# File: HUPA0019P.csv
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
# ********************
#
# === DUPLICATES ===
# Found CSV files: ['HUPA0002P.csv', 'HUPA0027P.csv', 'HUPA0020P.csv', 'HUPA0011P.csv', 'HUPA0007P.csv', 'HUPA0018P.csv', 'HUPA0028P.csv', 'HUPA0003P.csv', 'HUPA0022P.csv', 'HUPA0026P.csv', 'HUPA0025P.csv', 'HUPA0023P.csv', 'HUPA0005P.csv', 'HUPA0014P.csv', 'HUPA0001P.csv', 'HUPA0006P.csv', 'HUPA0010P.csv', 'HUPA0016P.csv', 'HUPA0021P.csv', 'HUPA0017P.csv', 'HUPA0024P.csv', 'HUPA0004P.csv', 'HUPA0009P.csv', 'HUPA0015P.csv', 'HUPA0019P.csv']
# ********************
# ************************************************************
# File: HUPA0002P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0027P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0020P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0011P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0007P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0018P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0028P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0003P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0022P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0026P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0025P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0023P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0005P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0014P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0001P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0006P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0010P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0016P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0021P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0017P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0024P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0004P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0009P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0015P.csv
#
#  Duplicates: 0
# ********************
# ************************************************************
# File: HUPA0019P.csv
#
#  Duplicates: 0
# ********************
#
# === OUTLIERS ===
# Found CSV files: ['HUPA0002P.csv', 'HUPA0027P.csv', 'HUPA0020P.csv', 'HUPA0011P.csv', 'HUPA0007P.csv', 'HUPA0018P.csv', 'HUPA0028P.csv', 'HUPA0003P.csv', 'HUPA0022P.csv', 'HUPA0026P.csv', 'HUPA0025P.csv', 'HUPA0023P.csv', 'HUPA0005P.csv', 'HUPA0014P.csv', 'HUPA0001P.csv', 'HUPA0006P.csv', 'HUPA0010P.csv', 'HUPA0016P.csv', 'HUPA0021P.csv', 'HUPA0017P.csv', 'HUPA0024P.csv', 'HUPA0004P.csv', 'HUPA0009P.csv', 'HUPA0015P.csv', 'HUPA0019P.csv']
# ********************
# ************************************************************
# File: HUPA0002P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >283.0
# calories: >39.08627204895011
# heart_rate: >102.80462519936198
# steps: >486.7999999999993
# basal_rate: >0.1416666666666666
# bolus_volume_delivered: >3.4199999999999817
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0027P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >266.6500000000039
# calories: >42.34640026092529
# heart_rate: >121.37366896677496
# steps: >500.0
# basal_rate: >0.118
# bolus_volume_delivered: >2.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0020P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >374.0
# calories: >30.84223985671997
# heart_rate: >112.3211924342105
# steps: >323.1699999999996
# basal_rate: >0.152
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0011P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >317.0
# calories: >24.081902675628655
# heart_rate: >110.39415384615386
# steps: >462.0
# basal_rate: >0.0
# bolus_volume_delivered: >0.0
# carb_input: >10.0
# ********************
# ************************************************************
# File: HUPA0007P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >355.8133333333334
# calories: >55.990359725952146
# heart_rate: >118.0564705882353
# steps: >455.44000000000005
# basal_rate: >0.1083333333333333
# bolus_volume_delivered: >5.432000000000016
# carb_input: >3.0
# ********************
# ************************************************************
# File: HUPA0018P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >328.7466666666666
# calories: >20.954424412250518
# heart_rate: >109.09831307729702
# steps: >337.05999999999995
# basal_rate: >0.0
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0028P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >222.0
# calories: >27.43169975221157
# heart_rate: >119.68872413793099
# steps: >445.0
# basal_rate: >0.045
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0003P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >327.53999999999996
# calories: >27.064078752994526
# heart_rate: >107.70745614035089
# steps: >318.2399999999998
# basal_rate: >0.0999999999999999
# bolus_volume_delivered: >2.765499999999997
# carb_input: >5.964999999999918
# ********************
# ************************************************************
# File: HUPA0022P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >211.0
# calories: >34.280399799346924
# heart_rate: >98.85820689655164
# steps: >442.79999999999745
# basal_rate: >0.25
# bolus_volume_delivered: >3.2779999999999743
# carb_input: >53.89999999999873
# ********************
# ************************************************************
# File: HUPA0026P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >334.9866666666664
# calories: >24.28992031097412
# heart_rate: >108.97818594104305
# steps: >481.9599999999991
# basal_rate: >0.087
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0025P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >210.31666666666658
# calories: >44.80880115032196
# heart_rate: >117.33701236263734
# steps: >332.0
# basal_rate: >0.1666666666666666
# bolus_volume_delivered: >3.8
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0023P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >226.0
# calories: >32.26518566370012
# heart_rate: >105.17197860962565
# steps: >311.920000000001
# basal_rate: >0.035
# bolus_volume_delivered: >1.6400000000003274
# carb_input: >4.410000000000082
# ********************
# ************************************************************
# File: HUPA0005P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >278.14333333333326
# calories: >18.077240126729013
# heart_rate: >110.96710227272719
# steps: >233.42999999999984
# basal_rate: >0.0833333333333333
# bolus_volume_delivered: >1.3
# carb_input: >1.0
# ********************
# ************************************************************
# File: HUPA0014P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >356.9240579710143
# calories: >25.702819995880127
# heart_rate: >117.48799999999997
# steps: >483.3199999999988
# basal_rate: >0.0
# bolus_volume_delivered: >5.0
# carb_input: >2.8599999999999
# ********************
# ************************************************************
# File: HUPA0001P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >396.0500000000002
# calories: >20.29002518951894
# heart_rate: >111.69299882629107
# steps: >318.15000000000055
# basal_rate: >0.0916666666666666
# bolus_volume_delivered: >1.5
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0006P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >387.3333333333333
# calories: >39.44678243637091
# heart_rate: >111.50484848484851
# steps: >418.1000000000013
# basal_rate: >0.1083333333333333
# bolus_volume_delivered: >4.8
# carb_input: >6.0
# ********************
# ************************************************************
# File: HUPA0010P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >330.34375
# calories: >20.34249997138977
# heart_rate: >110.76885888501742
# steps: >363.75
# basal_rate: >0.15
# bolus_volume_delivered: >1.18125
# carb_input: >1.0
# ********************
# ************************************************************
# File: HUPA0016P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >335.43999999999994
# calories: >27.936000185012816
# heart_rate: >122.2479799631977
# steps: >483.97999999999956
# basal_rate: >0.0999999999999999
# bolus_volume_delivered: >3.331999999999971
# carb_input: >4.0
# ********************
# ************************************************************
# File: HUPA0021P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >244.10666666666654
# calories: >23.197519917488098
# heart_rate: >114.52814814814812
# steps: >404.5799999999999
# basal_rate: >0.042
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0017P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >348.6666666666667
# calories: >23.475779542922975
# heart_rate: >121.97767650834402
# steps: >340.0
# basal_rate: >0.059
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0024P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >338.0
# calories: >36.66857957839966
# heart_rate: >108.81761119081769
# steps: >360.9399999999987
# basal_rate: >0.069
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0004P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >382.0
# calories: >32.15189792633058
# heart_rate: >104.337896389325
# steps: >322.1700000000001
# basal_rate: >0.1125
# bolus_volume_delivered: >7.917000000000008
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0009P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >293.05876095118884
# calories: >26.713773028850543
# heart_rate: >113.60459041591318
# steps: >493.8899999999999
# basal_rate: >0.1125
# bolus_volume_delivered: >1.4889999999999872
# carb_input: >0.5
# ********************
# ************************************************************
# File: HUPA0015P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >332.4533333333335
# calories: >31.68556288242342
# heart_rate: >126.88432648706323
# steps: >522.0900000000001
# basal_rate: >0.0
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0019P.csv
#
#  Possible outliers (values above 99th percentile):
# glucose: >329.0
# calories: >43.2411843299866
# heart_rate: >122.93823529411767
# steps: >549.9000000000001
# basal_rate: >0.069
# bolus_volume_delivered: >1.0
# carb_input: >1.0
# ********************

# %%
# Generate plots
outliers_folder = os.path.join(eda_output_folder, "outliers")
distributions_folder = os.path.join(eda_output_folder, "distributions")

os.makedirs(outliers_folder, exist_ok=True)
os.makedirs(distributions_folder, exist_ok=True)

print("\n GENERATING OUTLIER PLOTS ")
run_eda_on_folder(
    data_folder,
    funcs=[lambda df, file_name: plot_outliers(df, file_name, output_folder=outliers_folder)]
)

print("\nGENERATING DISTRIBUTION PLOTS ")
run_eda_on_folder(
    data_folder,
    funcs=[lambda df, file_name: plot_distributions(df, file_name, output_folder=distributions_folder)]
)
# Out:
#  GENERATING OUTLIER PLOTS
# Found CSV files: ['HUPA0002P.csv', 'HUPA0027P.csv', 'HUPA0020P.csv', 'HUPA0011P.csv', 'HUPA0007P.csv', 'HUPA0018P.csv', 'HUPA0028P.csv', 'HUPA0003P.csv', 'HUPA0022P.csv', 'HUPA0026P.csv', 'HUPA0025P.csv', 'HUPA0023P.csv', 'HUPA0005P.csv', 'HUPA0014P.csv', 'HUPA0001P.csv', 'HUPA0006P.csv', 'HUPA0010P.csv', 'HUPA0016P.csv', 'HUPA0021P.csv', 'HUPA0017P.csv', 'HUPA0024P.csv', 'HUPA0004P.csv', 'HUPA0009P.csv', 'HUPA0015P.csv', 'HUPA0019P.csv']
# ********************
# ************************************************************
# File: HUPA0002P.csv
# Saved outlier plots for HUPA0002P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0002P
# ********************
# ************************************************************
# File: HUPA0027P.csv
# Saved outlier plots for HUPA0027P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0027P
# ********************
# ************************************************************
# File: HUPA0020P.csv
# Saved outlier plots for HUPA0020P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0020P
# ********************
# ************************************************************
# File: HUPA0011P.csv
# Saved outlier plots for HUPA0011P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0011P
# ********************
# ************************************************************
# File: HUPA0007P.csv
# Saved outlier plots for HUPA0007P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0007P
# ********************
# ************************************************************
# File: HUPA0018P.csv
# Saved outlier plots for HUPA0018P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0018P
# ********************
# ************************************************************
# File: HUPA0028P.csv
# Saved outlier plots for HUPA0028P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0028P
# ********************
# ************************************************************
# File: HUPA0003P.csv
# Saved outlier plots for HUPA0003P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0003P
# ********************
# ************************************************************
# File: HUPA0022P.csv
# Saved outlier plots for HUPA0022P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0022P
# ********************
# ************************************************************
# File: HUPA0026P.csv
# Saved outlier plots for HUPA0026P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0026P
# ********************
# ************************************************************
# File: HUPA0025P.csv
# Saved outlier plots for HUPA0025P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0025P
# ********************
# ************************************************************
# File: HUPA0023P.csv
# Saved outlier plots for HUPA0023P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0023P
# ********************
# ************************************************************
# File: HUPA0005P.csv
# Saved outlier plots for HUPA0005P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0005P
# ********************
# ************************************************************
# File: HUPA0014P.csv
# Saved outlier plots for HUPA0014P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0014P
# ********************
# ************************************************************
# File: HUPA0001P.csv
# Saved outlier plots for HUPA0001P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0001P
# ********************
# ************************************************************
# File: HUPA0006P.csv
# Saved outlier plots for HUPA0006P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0006P
# ********************
# ************************************************************
# File: HUPA0010P.csv
# Saved outlier plots for HUPA0010P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0010P
# ********************
# ************************************************************
# File: HUPA0016P.csv
# Saved outlier plots for HUPA0016P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0016P
# ********************
# ************************************************************
# File: HUPA0021P.csv
# Saved outlier plots for HUPA0021P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0021P
# ********************
# ************************************************************
# File: HUPA0017P.csv
# Saved outlier plots for HUPA0017P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0017P
# ********************
# ************************************************************
# File: HUPA0024P.csv
# Saved outlier plots for HUPA0024P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0024P
# ********************
# ************************************************************
# File: HUPA0004P.csv
# Saved outlier plots for HUPA0004P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0004P
# ********************
# ************************************************************
# File: HUPA0009P.csv
# Saved outlier plots for HUPA0009P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0009P
# ********************
# ************************************************************
# File: HUPA0015P.csv
# Saved outlier plots for HUPA0015P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0015P
# ********************
# ************************************************************
# File: HUPA0019P.csv
# Saved outlier plots for HUPA0019P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/outliers/HUPA0019P
# ********************
#
# GENERATING DISTRIBUTION PLOTS
# Found CSV files: ['HUPA0002P.csv', 'HUPA0027P.csv', 'HUPA0020P.csv', 'HUPA0011P.csv', 'HUPA0007P.csv', 'HUPA0018P.csv', 'HUPA0028P.csv', 'HUPA0003P.csv', 'HUPA0022P.csv', 'HUPA0026P.csv', 'HUPA0025P.csv', 'HUPA0023P.csv', 'HUPA0005P.csv', 'HUPA0014P.csv', 'HUPA0001P.csv', 'HUPA0006P.csv', 'HUPA0010P.csv', 'HUPA0016P.csv', 'HUPA0021P.csv', 'HUPA0017P.csv', 'HUPA0024P.csv', 'HUPA0004P.csv', 'HUPA0009P.csv', 'HUPA0015P.csv', 'HUPA0019P.csv']
# ********************
# ************************************************************
# File: HUPA0002P.csv
# Saved distribution plots for HUPA0002P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0002P
# ********************
# ************************************************************
# File: HUPA0027P.csv
# Saved distribution plots for HUPA0027P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0027P
# ********************
# ************************************************************
# File: HUPA0020P.csv
# Saved distribution plots for HUPA0020P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0020P
# ********************
# ************************************************************
# File: HUPA0011P.csv
# Saved distribution plots for HUPA0011P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0011P
# ********************
# ************************************************************
# File: HUPA0007P.csv
# Saved distribution plots for HUPA0007P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0007P
# ********************
# ************************************************************
# File: HUPA0018P.csv
# Saved distribution plots for HUPA0018P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0018P
# ********************
# ************************************************************
# File: HUPA0028P.csv
# Saved distribution plots for HUPA0028P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0028P
# ********************
# ************************************************************
# File: HUPA0003P.csv
# Saved distribution plots for HUPA0003P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0003P
# ********************
# ************************************************************
# File: HUPA0022P.csv
# Saved distribution plots for HUPA0022P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0022P
# ********************
# ************************************************************
# File: HUPA0026P.csv
# Saved distribution plots for HUPA0026P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0026P
# ********************
# ************************************************************
# File: HUPA0025P.csv
# Saved distribution plots for HUPA0025P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0025P
# ********************
# ************************************************************
# File: HUPA0023P.csv
# Saved distribution plots for HUPA0023P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0023P
# ********************
# ************************************************************
# File: HUPA0005P.csv
# Saved distribution plots for HUPA0005P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0005P
# ********************
# ************************************************************
# File: HUPA0014P.csv
# Saved distribution plots for HUPA0014P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0014P
# ********************
# ************************************************************
# File: HUPA0001P.csv
# Saved distribution plots for HUPA0001P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0001P
# ********************
# ************************************************************
# File: HUPA0006P.csv
# Saved distribution plots for HUPA0006P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0006P
# ********************
# ************************************************************
# File: HUPA0010P.csv
# Saved distribution plots for HUPA0010P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0010P
# ********************
# ************************************************************
# File: HUPA0016P.csv
# Saved distribution plots for HUPA0016P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0016P
# ********************
# ************************************************************
# File: HUPA0021P.csv
# Saved distribution plots for HUPA0021P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0021P
# ********************
# ************************************************************
# File: HUPA0017P.csv
# Saved distribution plots for HUPA0017P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0017P
# ********************
# ************************************************************
# File: HUPA0024P.csv
# Saved distribution plots for HUPA0024P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0024P
# ********************
# ************************************************************
# File: HUPA0004P.csv
# Saved distribution plots for HUPA0004P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0004P
# ********************
# ************************************************************
# File: HUPA0009P.csv
# Saved distribution plots for HUPA0009P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0009P
# ********************
# ************************************************************
# File: HUPA0015P.csv
# Saved distribution plots for HUPA0015P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0015P
# ********************
# ************************************************************
# File: HUPA0019P.csv
# Saved distribution plots for HUPA0019P.csv in ../../Datasets/HUPA-UCM Diabetes Dataset/EDA_Outputs/distributions/HUPA0019P
# ********************

# %%
print("\n COMPREHENSIVE CHECK ")
run_eda_on_folder(data_folder, funcs=[
    show_shape,
    check_missing,
    check_duplicates,
    check_outliers
])
# Out:
# === COMPREHENSIVE CHECK ===
# Found CSV files: ['HUPA0002P.csv', 'HUPA0027P.csv', 'HUPA0020P.csv', 'HUPA0011P.csv', 'HUPA0007P.csv', 'HUPA0018P.csv', 'HUPA0028P.csv', 'HUPA0003P.csv', 'HUPA0022P.csv', 'HUPA0026P.csv', 'HUPA0025P.csv', 'HUPA0023P.csv', 'HUPA0005P.csv', 'HUPA0014P.csv', 'HUPA0001P.csv', 'HUPA0006P.csv', 'HUPA0010P.csv', 'HUPA0016P.csv', 'HUPA0021P.csv', 'HUPA0017P.csv', 'HUPA0024P.csv', 'HUPA0004P.csv', 'HUPA0009P.csv', 'HUPA0015P.csv', 'HUPA0019P.csv']
# ********************
# ************************************************************
# File: HUPA0002P.csv
#
#  Shape (rows, cols): (3181, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >283.0
# calories: >39.08627204895011
# heart_rate: >102.80462519936198
# steps: >486.7999999999993
# basal_rate: >0.1416666666666666
# bolus_volume_delivered: >3.4199999999999817
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0027P.csv
#
#  Shape (rows, cols): (165306, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >266.6500000000039
# calories: >42.34640026092529
# heart_rate: >121.37366896677496
# steps: >500.0
# basal_rate: >0.118
# bolus_volume_delivered: >2.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0020P.csv
#
#  Shape (rows, cols): (2862, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >374.0
# calories: >30.84223985671997
# heart_rate: >112.3211924342105
# steps: >323.1699999999996
# basal_rate: >0.152
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0011P.csv
#
#  Shape (rows, cols): (3839, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >317.0
# calories: >24.081902675628655
# heart_rate: >110.39415384615386
# steps: >462.0
# basal_rate: >0.0
# bolus_volume_delivered: >0.0
# carb_input: >10.0
# ********************
# ************************************************************
# File: HUPA0007P.csv
#
#  Shape (rows, cols): (3857, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >355.8133333333334
# calories: >55.990359725952146
# heart_rate: >118.0564705882353
# steps: >455.44000000000005
# basal_rate: >0.1083333333333333
# bolus_volume_delivered: >5.432000000000016
# carb_input: >3.0
# ********************
# ************************************************************
# File: HUPA0018P.csv
#
#  Shape (rows, cols): (3895, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >328.7466666666666
# calories: >20.954424412250518
# heart_rate: >109.09831307729702
# steps: >337.05999999999995
# basal_rate: >0.0
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0028P.csv
#
#  Shape (rows, cols): (25902, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >222.0
# calories: >27.43169975221157
# heart_rate: >119.68872413793099
# steps: >445.0
# basal_rate: >0.045
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0003P.csv
#
#  Shape (rows, cols): (3770, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >327.53999999999996
# calories: >27.064078752994526
# heart_rate: >107.70745614035089
# steps: >318.2399999999998
# basal_rate: >0.0999999999999999
# bolus_volume_delivered: >2.765499999999997
# carb_input: >5.964999999999918
# ********************
# ************************************************************
# File: HUPA0022P.csv
#
#  Shape (rows, cols): (4023, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >211.0
# calories: >34.280399799346924
# heart_rate: >98.85820689655164
# steps: >442.79999999999745
# basal_rate: >0.25
# bolus_volume_delivered: >3.2779999999999743
# carb_input: >53.89999999999873
# ********************
# ************************************************************
# File: HUPA0026P.csv
#
#  Shape (rows, cols): (40605, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >334.9866666666664
# calories: >24.28992031097412
# heart_rate: >108.97818594104305
# steps: >481.9599999999991
# basal_rate: >0.087
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0025P.csv
#
#  Shape (rows, cols): (4006, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >210.31666666666658
# calories: >44.80880115032196
# heart_rate: >117.33701236263734
# steps: >332.0
# basal_rate: >0.1666666666666666
# bolus_volume_delivered: >3.8
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0023P.csv
#
#  Shape (rows, cols): (3919, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >226.0
# calories: >32.26518566370012
# heart_rate: >105.17197860962565
# steps: >311.920000000001
# basal_rate: >0.035
# bolus_volume_delivered: >1.6400000000003274
# carb_input: >4.410000000000082
# ********************
# ************************************************************
# File: HUPA0005P.csv
#
#  Shape (rows, cols): (3858, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >278.14333333333326
# calories: >18.077240126729013
# heart_rate: >110.96710227272719
# steps: >233.42999999999984
# basal_rate: >0.0833333333333333
# bolus_volume_delivered: >1.3
# carb_input: >1.0
# ********************
# ************************************************************
# File: HUPA0014P.csv
#
#  Shape (rows, cols): (3829, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >356.9240579710143
# calories: >25.702819995880127
# heart_rate: >117.48799999999997
# steps: >483.3199999999988
# basal_rate: >0.0
# bolus_volume_delivered: >5.0
# carb_input: >2.8599999999999
# ********************
# ************************************************************
# File: HUPA0001P.csv
#
#  Shape (rows, cols): (4096, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >396.0500000000002
# calories: >20.29002518951894
# heart_rate: >111.69299882629107
# steps: >318.15000000000055
# basal_rate: >0.0916666666666666
# bolus_volume_delivered: >1.5
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0006P.csv
#
#  Shape (rows, cols): (2290, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >387.3333333333333
# calories: >39.44678243637091
# heart_rate: >111.50484848484851
# steps: >418.1000000000013
# basal_rate: >0.1083333333333333
# bolus_volume_delivered: >4.8
# carb_input: >6.0
# ********************
# ************************************************************
# File: HUPA0010P.csv
#
#  Shape (rows, cols): (2976, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >330.34375
# calories: >20.34249997138977
# heart_rate: >110.76885888501742
# steps: >363.75
# basal_rate: >0.15
# bolus_volume_delivered: >1.18125
# carb_input: >1.0
# ********************
# ************************************************************
# File: HUPA0016P.csv
#
#  Shape (rows, cols): (3835, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >335.43999999999994
# calories: >27.936000185012816
# heart_rate: >122.2479799631977
# steps: >483.97999999999956
# basal_rate: >0.0999999999999999
# bolus_volume_delivered: >3.331999999999971
# carb_input: >4.0
# ********************
# ************************************************************
# File: HUPA0021P.csv
#
#  Shape (rows, cols): (2343, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >244.10666666666654
# calories: >23.197519917488098
# heart_rate: >114.52814814814812
# steps: >404.5799999999999
# basal_rate: >0.042
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0017P.csv
#
#  Shape (rows, cols): (3599, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >348.6666666666667
# calories: >23.475779542922975
# heart_rate: >121.97767650834402
# steps: >340.0
# basal_rate: >0.059
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0024P.csv
#
#  Shape (rows, cols): (2902, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >338.0
# calories: >36.66857957839966
# heart_rate: >108.81761119081769
# steps: >360.9399999999987
# basal_rate: >0.069
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0004P.csv
#
#  Shape (rows, cols): (3184, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >382.0
# calories: >32.15189792633058
# heart_rate: >104.337896389325
# steps: >322.1700000000001
# basal_rate: >0.1125
# bolus_volume_delivered: >7.917000000000008
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0009P.csv
#
#  Shape (rows, cols): (3812, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >293.05876095118884
# calories: >26.713773028850543
# heart_rate: >113.60459041591318
# steps: >493.8899999999999
# basal_rate: >0.1125
# bolus_volume_delivered: >1.4889999999999872
# carb_input: >0.5
# ********************
# ************************************************************
# File: HUPA0015P.csv
#
#  Shape (rows, cols): (3792, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >332.4533333333335
# calories: >31.68556288242342
# heart_rate: >126.88432648706323
# steps: >522.0900000000001
# basal_rate: >0.0
# bolus_volume_delivered: >0.0
# carb_input: >0.0
# ********************
# ************************************************************
# File: HUPA0019P.csv
#
#  Shape (rows, cols): (3711, 8)
#
#  Missing values:
# time                      0
# glucose                   0
# calories                  0
# heart_rate                0
# steps                     0
# basal_rate                0
# bolus_volume_delivered    0
# carb_input                0
# dtype: int64
#
#  Duplicates: 0
#
#  Possible outliers (values above 99th percentile):
# glucose: >329.0
# calories: >43.2411843299866
# heart_rate: >122.93823529411767
# steps: >549.9000000000001
# basal_rate: >0.069
# bolus_volume_delivered: >1.0
# carb_input: >1.0
# ********************
